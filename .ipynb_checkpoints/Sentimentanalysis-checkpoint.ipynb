# %% [markdown]
# # Installed Modules

# %% [markdown]
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install nltk
# !pip install texblob
# !pip install pandas emoji
# !pip install emot
# !pip install textblob
# !pip install wordcloud
# !pip install imbalanced-learn

# %% [markdown]
# # Imported  Data Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Imported Nlp Text Libraries

# %%
import string
import re
import nltk
import nltk.corpus
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\srisa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\srisa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\srisa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Loading Dataset

# %%
data=pd.read_csv("Restaurant reviews.csv")

# %%
data.head()
# Out:
#         Restaurant              Reviewer  \
# 0  Beyond Flavours     Rusha Chakraborty
# 1  Beyond Flavours  Anusha Tirumalaneedi
# 2  Beyond Flavours       Ashok Shekhawat
# 3  Beyond Flavours        Swapnil Sarkar
# 4  Beyond Flavours                Dileep
#
#                                               Review Rating  \
# 0  The ambience was good, food was quite good . h...      5
# 1  Ambience is too good for a pleasant evening. S...      5
# 2  A must try.. great food great ambience. Thnx f...      5
# 3  Soumen das and Arun was a great guy. Only beca...      5
# 4  Food is good.we ordered Kodi drumsticks and ba...      5
#
#                   Metadata             Time  Pictures    7514
# 0   1 Review , 2 Followers  5/25/2019 15:54         0  2447.0
# 1  3 Reviews , 2 Followers  5/25/2019 14:20         0     NaN
# 2  2 Reviews , 3 Followers  5/24/2019 22:54         0     NaN
# 3    1 Review , 1 Follower  5/24/2019 22:11         0     NaN
# 4  3 Reviews , 2 Followers  5/24/2019 21:37         0     NaN

# %% [markdown]
# # Data Preprocessing

# %%
data.drop(columns=["Restaurant","Reviewer","Metadata","Time","Pictures","7514"],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                               Review Rating
# 0  The ambience was good, food was quite good . h...      5
# 1  Ambience is too good for a pleasant evening. S...      5
# 2  A must try.. great food great ambience. Thnx f...      5
# 3  Soumen das and Arun was a great guy. Only beca...      5
# 4  Food is good.we ordered Kodi drumsticks and ba...      5

# %%
data.shape
# Out:
# (10000, 2)

# %%
data.isnull().sum()
# Out:
# Review    45
# Rating    38
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %%
data["Rating"].unique()
# Out:
# array(['5', '4', '1', '3', '2', '3.5', '4.5', '2.5', '1.5', 'Like'],
#       dtype=object)

# %%
data=data[data["Rating"]!="Like"]

# %%
data['Rating'] = pd.to_numeric(data['Rating'])

# %%
rating_counts=data['Rating'].value_counts().sort_index()

# %%
rating_counts
# Out:
# Rating
# 1.0    1735
# 1.5       9
# 2.0     684
# 2.5      19
# 3.0    1192
# 3.5      47
# 4.0    2373
# 4.5      69
# 5.0    3826
# Name: count, dtype: int64

# %%
my_labels=[f'Rating{i}'for i in rating_counts.index]
values=rating_counts.values

# %%
values
# Out:
# array([1735,    9,  684,   19, 1192,   47, 2373,   69, 3826], dtype=int64)

# %%
plt.figure(figsize=(15,10))
plt.pie(values,labels=my_labels,autopct='%1.1f%%',shadow=True)
plt.legend()
plt.title("Distribution of Ratings")
plt.show()

# %% [markdown]
# # Text Preprocesing

# %%
import emoji

# %%
def Text_Cleaning(Text):
    Text=Text.lower()
    # Remove punctuation
    punc=str.maketrans(string.punctuation, ' ' * len(string.punctuation))
    Text=Text.translate(punc)
    # Remove digits
    Text=re.sub(r'\d', '', Text)
    # Remove URLs
    Text=re.sub('https?://\S+|www\.\S+', '', Text)
    # Remove newline characters
    Text=re.sub('\n', '', Text)
    # Remove emojis
    Text=emoji.replace_emoji(Text, replace='')
    # Remove emoticons
    emoticon_pattern = r'(?::|;|=)(?:-)?(?:\)|\(|D|P)'
    Text=re.sub(emoticon_pattern, '', Text)

    return Text

# %%
Stopwords=stopwords.words('english')
def Text_Processing(Text):
    Processed_Text=list()
    Lemmatizer=WordNetLemmatizer()
    Tokens=nltk.word_tokenize(Text)
    for word in Tokens:
        if word not in Stopwords:
            Processed_Text.append(Lemmatizer.lemmatize(word))
    return(" ".join(Processed_Text))

# %%
data["cleaned_review"]=data["Review"].apply(lambda Text: Text_Cleaning(Text))
data["cleaned_review"]=data["Review"].apply(lambda Text: Text_Processing(Text))

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                                       cleaned_review
# 0  The ambience good , food quite good . Saturday...
# 1  Ambience good pleasant evening . Service promp...
# 2  A must try .. great food great ambience . Thnx...
# 3  Soumen da Arun great guy . Only behavior since...
# 4  Food good.we ordered Kodi drumstick basket mut...

# %%
def Labelling(Rows):
    if(Rows["Rating"]>=3.0):
        Label="Positive"
    else:
        Label="Negative"
    
    return Label    
data["sentiment"]=data.apply(Labelling,axis=1)

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                                       cleaned_review sentiment
# 0  The ambience good , food quite good . Saturday...  Positive
# 1  Ambience good pleasant evening . Service promp...  Positive
# 2  A must try .. great food great ambience . Thnx...  Positive
# 3  Soumen da Arun great guy . Only behavior since...  Positive
# 4  Food good.we ordered Kodi drumstick basket mut...  Positive

# %%
sentiment_counts=data["sentiment"].value_counts()

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(10,6))
plt.bar(sentiment_counts.index,sentiment_counts.values,color="indigo")
plt.title("Distribution of Sentiments Based on Rating")
plt.xlabel("Sentiments")
plt.ylabel("Count")
plt.show()

# %%
data["polarity"]=data["cleaned_review"].map(lambda Text: TextBlob(Text).sentiment.polarity)

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                                       cleaned_review sentiment  polarity
# 0  The ambience good , food quite good . Saturday...  Positive  0.660000
# 1  Ambience good pleasant evening . Service promp...  Positive  0.708333
# 2  A must try .. great food great ambience . Thnx...  Positive  0.540000
# 3  Soumen da Arun great guy . Only behavior since...  Positive  0.500000
# 4  Food good.we ordered Kodi drumstick basket mut...  Positive  0.525000

# %%
plt.figure(figsize=(10,6))
plt.hist(data["polarity"],bins=50,color="pink",linewidth=1,edgecolor="black")
plt.xlabel("Polarity")
plt.ylabel("Count of Reviews")
plt.title("Polarity Score")
plt.show()

# %%
data["word_counts"]=data["cleaned_review"].apply(lambda x: len(str(x).split()))

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                                       cleaned_review sentiment  polarity  \
# 0  The ambience good , food quite good . Saturday...  Positive  0.660000
# 1  Ambience good pleasant evening . Service promp...  Positive  0.708333
# 2  A must try .. great food great ambience . Thnx...  Positive  0.540000
# 3  Soumen da Arun great guy . Only behavior since...  Positive  0.500000
# 4  Food good.we ordered Kodi drumstick basket mut...  Positive  0.525000
#
#    word_counts
# 0           32
# 1           20
# 2           28
# 3           21
# 4           26

# %%
plt.figure(figsize=(10,6))
plt.hist(data["word_counts"],bins=40,color="brown",linewidth=1,edgecolor="white")
plt.xlabel("Word_Counts")
plt.ylabel("Count of Reviews")
plt.title("Word Counts in Reviews")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud

# %% [markdown]
# # Gram Analysis

# %%
def Gram_Analysis(Corpus,Gram,N):
    Vectorizer=CountVectorizer(stop_words=Stopwords,ngram_range=(Gram,Gram))
    ngrams=Vectorizer.fit_transform(Corpus)
    Count=ngrams.sum(axis=0)
    words=[(word,Count[0,idx]) for word,idx in Vectorizer.vocabulary_.items()]
    words=sorted(words,key=lambda x:x[1],reverse=True)
    return words[:N]

# %%
Positive=data[data["sentiment"]=="Positive"].dropna()
Negative=data[data["sentiment"]=="Negative"].dropna()

# %% [markdown]
# # Unigram Analysis

# %%
words=Gram_Analysis(Positive["cleaned_review"],1,30)
Unigram_pos=pd.DataFrame(words,columns=["Words","Counts"])
Unigram_pos=Unigram_pos.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Unigram_pos.index,Unigram_pos,color="green")
plt.title("Unigram of Reviews with Positive Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %%
words=Gram_Analysis(Negative["cleaned_review"],1,30)
Unigram_neg=pd.DataFrame(words,columns=["Words","Counts"])
Unigram_neg=Unigram_neg.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Unigram_neg.index,Unigram_neg,color="red")
plt.title("Unigram of Reviews with Negative Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %% [markdown]
# # Bigram Analysis

# %%
words=Gram_Analysis(Positive["cleaned_review"],2,30)
Bigram_pos=pd.DataFrame(words,columns=["Words","Counts"])
Bigram_pos=Bigram_pos.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Bigram_pos.index,Bigram_pos,color="green")
plt.title("Bigram of Reviews with Positive Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %%
words=Gram_Analysis(Negative["cleaned_review"],2,30)
Bigram_neg=pd.DataFrame(words,columns=["Words","Counts"])
Bigram_neg=Bigram_neg.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Bigram_neg.index,Bigram_neg,color="red")
plt.title("Bigram of Reviews with Negative Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %% [markdown]
# # Trigram Analysis

# %%
words=Gram_Analysis(Positive["cleaned_review"],3,30)
Trigram_pos=pd.DataFrame(words,columns=["Words","Counts"])
Trigram_pos=Trigram_pos.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Trigram_pos.index,Trigram_pos,color="green")
plt.title("Trigram of Reviews with Positive Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %%
words=Gram_Analysis(Negative["cleaned_review"],3,30)
Trigram_neg=pd.DataFrame(words,columns=["Words","Counts"])
Trigram_neg=Trigram_neg.groupby("Words").sum()["Counts"].sort_values()

# %%
plt.figure(figsize=(10,6))
plt.barh(Trigram_neg.index,Trigram_neg,color="red")
plt.title("Trigram of Reviews with Negative Sentiments")
plt.xlabel("Total Count")
plt.ylabel("Top Words")
plt.show()

# %% [markdown]
# # Building Wordclouds

# %%
wordcloud=WordCloud(max_words=50,width=3000,height=1500,stopwords=Stopwords).generate(str(Positive["cleaned_review"]))
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud=WordCloud(max_words=50,width=3000,height=1500,stopwords=Stopwords,colormap="Reds").generate(str(Negative["cleaned_review"]))
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  The ambience was good, food was quite good . h...     5.0
# 1  Ambience is too good for a pleasant evening. S...     5.0
# 2  A must try.. great food great ambience. Thnx f...     5.0
# 3  Soumen das and Arun was a great guy. Only beca...     5.0
# 4  Food is good.we ordered Kodi drumsticks and ba...     5.0
#
#                                       cleaned_review sentiment  polarity  \
# 0  The ambience good , food quite good . Saturday...  Positive  0.660000
# 1  Ambience good pleasant evening . Service promp...  Positive  0.708333
# 2  A must try .. great food great ambience . Thnx...  Positive  0.540000
# 3  Soumen da Arun great guy . Only behavior since...  Positive  0.500000
# 4  Food good.we ordered Kodi drumstick basket mut...  Positive  0.525000
#
#    word_counts
# 0           32
# 1           20
# 2           28
# 3           21
# 4           26

# %%
data.drop(columns=["Review","polarity","word_counts","Rating"],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                       cleaned_review sentiment
# 0  The ambience good , food quite good . Saturday...  Positive
# 1  Ambience good pleasant evening . Service promp...  Positive
# 2  A must try .. great food great ambience . Thnx...  Positive
# 3  Soumen da Arun great guy . Only behavior since...  Positive
# 4  Food good.we ordered Kodi drumstick basket mut...  Positive

# %% [markdown]
# # Feature Engineering

# %%
#Tfidf Vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
#resampling
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# # Splitting of Data

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.cleaned_review
y = data.sentiment

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from imblearn.pipeline import Pipeline

# %%
tfid_vectorizer = TfidfVectorizer()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Logistic Regression

# %%
logistic_Regressor = LogisticRegression()

# %%
Regressor=Pipeline(steps=[('vectorizer', tfid_vectorizer),("ROS", RandomOverSampler()), ('classifier', logistic_Regressor)])
Regressor.fit(X_train,y_train)
y_pred_Regressor=Regressor.predict(X_test)
print(accuracy_score(y_test,y_pred_Regressor))
print(classification_report(y_test,y_pred_Regressor))
# Out:
# 0.8935315387705905
#               precision    recall  f1-score   support
#
#     Negative       0.74      0.88      0.81       621
#     Positive       0.96      0.90      0.93      1868
#
#     accuracy                           0.89      2489
#    macro avg       0.85      0.89      0.87      2489
# weighted avg       0.90      0.89      0.90      2489

# %%
confusion_matrix_Regressor = confusion_matrix(y_test, y_pred_Regressor)
plt.imshow(confusion_matrix_Regressor, cmap='Reds', interpolation='nearest')
plt.colorbar()
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
support_vector_classifier = SVC()
SVC_classifier = Pipeline(steps=[('vectorizer', tfid_vectorizer),("ROS", RandomOverSampler()), ('classifier', support_vector_classifier)])
SVC_classifier.fit(X_train,y_train)
y_pred_SVC_classifier = SVC_classifier.predict(X_test)
print(accuracy_score(y_test,y_pred_SVC_classifier))
print(classification_report(y_test,y_pred_SVC_classifier))
# Out:
# 0.9055845721173162
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.78      0.80       621
#     Positive       0.93      0.95      0.94      1868
#
#     accuracy                           0.91      2489
#    macro avg       0.88      0.86      0.87      2489
# weighted avg       0.90      0.91      0.90      2489

# %%
confusion_matrix_SVC = confusion_matrix(y_test, y_pred_SVC_classifier)
plt.imshow(confusion_matrix_SVC, cmap='inferno', interpolation='nearest')
plt.colorbar()
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #  Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_classifier = RandomForestClassifier()
rf_classifier = Pipeline(steps=[('victorizer', tfid_vectorizer),("ROS", RandomOverSampler(sampling_strategy="not majority")), ('classifier',random_forest_classifier )])
rf_classifier.fit(X_train,y_train)
y_pred_rf_classifier = rf_classifier.predict(X_test)
print(accuracy_score(y_test,y_pred_rf_classifier))
print(classification_report(y_test,y_pred_rf_classifier))
# Out:
# 0.9003615910004018
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.75      0.79       621
#     Positive       0.92      0.95      0.93      1868
#
#     accuracy                           0.90      2489
#    macro avg       0.88      0.85      0.86      2489
# weighted avg       0.90      0.90      0.90      2489

# %%
confusion_matrix_rf=confusion_matrix(y_test,y_pred_rf_classifier)
plt.imshow(confusion_matrix_rf, cmap='plasma', interpolation='nearest')
plt.colorbar()
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Predicting Sentiments of Some Sample Reviews

# %%
new_review1 =["An excellent choice for a special night out. The ambiance is romantic, the service is top-notch, and the food is simply amazing. The lamb shank was tender and juicy, and the dessert was a perfect end to a great meal."]
vectorized_review2 = tfid_vectorizer.transform(new_review1)
result =support_vector_classifier.predict(vectorized_review2)
for i in result:
  print(i)
# Out:
# Positive

# %%
new_review2 = ["Absolutely terrible. The food took forever to arrive, and when it did, it was inedible. The chicken was raw in the middle, and the salad was wilted and unappealing. The staff were unapologetic and didn't seem to care about our complaints. I left feeling frustrated and hungry. Never going back."]
vectorized_review2 = tfid_vectorizer.transform(new_review2)
result =support_vector_classifier.predict(vectorized_review2)
for i in result:
  print(i)
# Out:
# Negative

# %% [markdown]
# # Loading and Dumping The Model into Pickle File

# %%
import pickle

# %%
with open('svc_sentiment_model.pkl', 'wb') as file:
    pickle.dump(SVC_classifier, file)
with open('svc_sentiment_model.pkl', 'rb') as file:
    loaded_svc_model=pickle.load(file)
